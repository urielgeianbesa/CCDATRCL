# %% [markdown]
# # Exercise 5

# %% [markdown]
# #### 1. Create a dictionary of your 10 favorite songs.

# %% [markdown]
# Example:
#
# |KEY|VALUE|
# |---|---|
# |001|My Love|
# |002|Like a rose|

# %%
# put your answer here
mydictionary = {
  "001": "Angels Brought me Here ",
  "002": "Aking Pahinga",
  "003": "I'd Rather",
  "004": "Here With Me",
  "005": "Enchanted",
  "006": "So Big" ,
  "007": "Solo",
  "008": "Goo Goo Dolls",
  "009": "Incomplete",
  "010": "Battle Cry "
}
print(mydictionary)
# Out:
# {'001': 'Angels Brought me Here ', '002': 'Aking Pahinga', '003': "I'd Rather", '004': 'Here With Me', '005': 'Enchanted', '006': 'So Big', '007': 'Solo', '008': 'Goo Goo Dolls', '009': 'Incomplete', '010': 'Battle Cry '}

# %% [markdown]
# #### 2. Loop through the dictionary by its **key** and **value**

# %%
# put your answer here
for x, y in mydictionary.items():
  print(x, y)
# Out:
# 001 Angels Brought me Here
# 002 Aking Pahinga
# 003 I'd Rather
# 004 Here With Me
# 005 Enchanted
# 006 So Big
# 007 Solo
# 008 Goo Goo Dolls
# 009 Incomplete
# 010 Battle Cry

# %% [markdown]
# #### 3. Add one additional song

# %%
# put your answer here
mydictionary["011"] = "Flying Me to the moon"
mydictionary
# Out:
# {'001': 'Angels Brought me Here ',
#  '002': 'Aking Pahinga',
#  '003': "I'd Rather",
#  '004': 'Here With Me',
#  '005': 'Enchanted',
#  '006': 'So Big',
#  '007': 'Solo',
#  '008': 'Goo Goo Dolls',
#  '009': 'Incomplete',
#  '010': 'Battle Cry ',
#  '011': 'Flying Me to the moon'}

# %% [markdown]
# #### 4. Remove one song

# %%
# put your answer here
mydictionary.pop("005")
mydictionary
# Out:
# {'001': 'Angels Brought me Here ',
#  '002': 'Aking Pahinga',
#  '003': "I'd Rather",
#  '004': 'Here With Me',
#  '006': 'So Big',
#  '007': 'Solo',
#  '008': 'Goo Goo Dolls',
#  '009': 'Incomplete',
#  '010': 'Battle Cry ',
#  '011': 'Flying Me to the moon'}

# %% [markdown]
# #### 5. Create a nested dictionary of your 10 favorite songs with 5 genres. Display all of the items of the nested dictionary
#
# - Each nested dictionary's key should be the genre of the song
# - Put each song in their respective genre

# %% [markdown]
# Example:
#
#
# |KEY|VALUE|
# |---|---|
# |Pop|{001, Baby}|
# |Rock|{001, Enter Sandman}|

# %%
# put your answer here
mydictionary = {
  "RnB" : {
    "003" : "I'd Rather",
    "011" : "Flying Me to the moon" ,
    "009" : "Incomplete",
    "004": "Here With Me" ,
    "002": "Aking Pahinga" ,
    "001": "Angels Brought me Here"
  },
  "Rock" : {
    "008" : "Goo Goo Dolls",
    "010" : "Battle Cry"
  },
  "Rap" : {
    "006" : "So Big",
    "007" : "Solo"
  }
}

mydictionary
# Out:
# {'RnB': {'003': "I'd Rather",
#   '011': 'Flying Me to the moon',
#   '009': 'Incomplete',
#   '004': 'Here With Me',
#   '002': 'Aking Pahinga',
#   '001': 'Angels Brought me Here'},
#  'Rock': {'008': 'Goo Goo Dolls', '010': 'Battle Cry'},
#  'Rap': {'006': 'So Big', '007': 'Solo'}}

# %% [markdown]
# #### 6. Print the first song of the first genre

# %%
# put your answer here
print(mydictionary["RnB"]["003"])
# Out:
# I'd Rather

# %% [markdown]
# #### 7. Print the first song of the last genre

# %%
# put your answer here
print(mydictionary["Rap"]["007"])
# Out:
# Solo
